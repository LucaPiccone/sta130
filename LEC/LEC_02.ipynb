# %%
# Sept 16, 2024

# %%
# logical conditionals for the purpose of 
# boolean expression

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/KeithGalli/pandas/master/pokemon_data.csv"
# fail https://github.com/KeithGalli/pandas/blob/master/pokemon_data.csv
pokeaman = pd.read_csv(url)

# %%
pokeaman.sort_values('Attack', ascending=False)
# Out:
#        #                     Name   Type 1    Type 2   HP  Attack  Defense  \
# 163  150      MewtwoMega Mewtwo X  Psychic  Fighting  106     190      100
# 232  214  HeracrossMega Heracross      Bug  Fighting   80     185      115
# 424  383    GroudonPrimal Groudon   Ground      Fire  100     180      160
# 426  384    RayquazaMega Rayquaza   Dragon    Flying  105     180      100
# 429  386       DeoxysAttack Forme  Psychic       NaN   50     180       20
# ..   ...                      ...      ...       ...  ...     ...      ...
# 139  129                 Magikarp    Water       NaN   20      10       55
# 261  242                  Blissey   Normal       NaN  255      10       10
# 230  213                  Shuckle      Bug      Rock   20      10      230
# 121  113                  Chansey   Normal       NaN  250       5        5
# 488  440                  Happiny   Normal       NaN  100       5        5
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
# Boolean selection. 
# Only pokeman that are legendary
pokeaman[pokeaman['Legendary']]
# Out:
#        #                 Name    Type 1    Type 2   HP  Attack  Defense  \
# 156  144             Articuno       Ice    Flying   90      85      100
# 157  145               Zapdos  Electric    Flying   90      90       85
# 158  146              Moltres      Fire    Flying   90     100       90
# 162  150               Mewtwo   Psychic       NaN  106     110       90
# 163  150  MewtwoMega Mewtwo X   Psychic  Fighting  106     190      100
# ..   ...                  ...       ...       ...  ...     ...      ...
# 795  719              Diancie      Rock     Fairy   50     100      150
# 796  719  DiancieMega Diancie      Rock     Fairy   50     160      110
# 797  720  HoopaHoopa Confined   Psychic     Ghost   80     110       60
# 798  720   HoopaHoopa Unbound   Psychic      Dark   80     160       60
# 799  721            Volcanion      Fire     Water   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
pokeaman[pokeaman['Type 2'] == 'Ghost']
pokeaman[pokeaman['Type 1'] == 'Ghost']
# Can't be both, type 1 = ghost and type 2 = ghost
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 99    92                 Gastly  Ghost  Poison   30      35       30      100
# 100   93                Haunter  Ghost  Poison   45      50       45      115
# 101   94                 Gengar  Ghost  Poison   60      65       60      130
# 102   94      GengarMega Gengar  Ghost  Poison   60      65       80      170
# 215  200             Misdreavus  Ghost     NaN   60      60       60       85
# 385  353                Shuppet  Ghost     NaN   44      75       35       63
# 386  354                Banette  Ghost     NaN   64     115       65       83
# 387  354    BanetteMega Banette  Ghost     NaN   64     165       75       93
# 388  355                Duskull  Ghost     NaN   20      40       90       30
# 389  356               Dusclops  Ghost     NaN   40      70      130       60
# 472  425               Drifloon  Ghost  Flying   90      50       34       60
# ...

# %%
pokeaman[ (pokeaman["HP"] > 80) & (pokeaman["Type 2"] == "Fighting") ]
# Out:
#        #                     Name   Type 1    Type 2   HP  Attack  Defense  \
# 67    62                Poliwrath    Water  Fighting   90      95       95
# 163  150      MewtwoMega Mewtwo X  Psychic  Fighting  106     190      100
# 504  454                Toxicroak   Poison  Fighting   83     106       65
# 558  499                  Pignite     Fire  Fighting   90      93       55
# 559  500                   Emboar     Fire  Fighting  110     123       65
# 699  638                 Cobalion    Steel  Fighting   91      90      129
# 700  639                Terrakion     Rock  Fighting   91     129       90
# 701  640                 Virizion    Grass  Fighting   91      90       72
# 713  647     KeldeoOrdinary Forme    Water  Fighting   91      72       90
# 714  647     KeldeoResolute Forme    Water  Fighting   91      72       90
# 716  648  MeloettaPirouette Forme   Normal  Fighting  100     128       90
# ...

# %%
pokeaman[ (pokeaman["HP"] > 80) | (pokeaman["Type 2"] == "Fighting") ]
# Out:
#        #                 Name  Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 22    18              Pidgeot  Normal  Flying   83      80       75       70
# 23    18  PidgeotMega Pidgeot  Normal  Flying   83      80       80      135
# 36    31            Nidoqueen  Poison  Ground   90      92       87       75
# 39    34             Nidoking  Poison  Ground   81     102       77       85
# 41    36             Clefable   Fairy     NaN   95      70       73       95
# ..   ...                  ...     ...     ...  ...     ...      ...      ...
# 789  713              Avalugg     Ice     NaN   95     117      184       44
# 791  715              Noivern  Flying  Dragon   85      70       80       97
# 792  716              Xerneas   Fairy     NaN  126     131       95      131
# 793  717              Yveltal    Dark  Flying  126     131       95      131
# 794  718     Zygarde50% Forme  Dragon  Ground  108     100      121       81
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %%
pokeaman.dtypes
# Out:
# #              int64
# Name          object
# Type 1        object
# Type 2        object
# HP             int64
# Attack         int64
# Defense        int64
# Sp. Atk        int64
# Sp. Def        int64
# Speed          int64
# Generation     int64
# Legendary       bool
# dtype: object

# %%
pokeaman[ (pokeaman['Attack'] < 50) & (pokeaman['Defense'] > 100) ]
# Out:
#        #                Name Type 1   Type 2   HP  Attack  Defense  Sp. Atk  \
# 103   95                Onix   Rock   Ground   35      45      160       30
# 230  213             Shuckle    Bug     Rock   20      10      230       10
# 323  299            Nosepass   Rock      NaN   30      45      135       45
# 455  410            Shieldon   Rock    Steel   30      42      118       42
# 616  555  DarmanitanZen Mode   Fire  Psychic  105      30      105      140
#
#      Sp. Def  Speed  Generation  Legendary
# 103       45     70           1      False
# 230      230      5           2      False
# 323       90     30           3      False
# 455       88     30           4      False
# 616      105     55           5      False

# %%
# pokeaman[logical_conditional]
pokeaman[4:10]
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
# 9  7                   Squirtle  Water     NaN  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary
# 4       50     65           1      False
# 5       65     80           1      False
# 6       85    100           1      False
# 7       85    100           1      False
# 8      115    100           1      False
# 9       64     43           1      False

# %%
# With iloc you can index the columns
pokeaman.iloc[4:10, 3:5]
# Out:
#    Type 2  HP
# 4     NaN  39
# 5     NaN  58
# 6  Flying  78
# 7  Dragon  78
# 8  Flying  78
# 9     NaN  44

# %%
# .loc
pokeaman[4:10, ['Attack', 'Defence']]

# know the difference way to index dataframes.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:173, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(4, 10, None), ['Attack', 'Defence'])' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[61], line 2
#       1 # .loc
# ----> 2 pokeaman[4:10, ['Attack', 'Defence']]
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
# ...

# %% [markdown]
# little x is what actually happened
# The concept of an event and the actual happening of the event
#
# We will use P(A) for the probability of an event.
# Pr(A) or Pr(X = x)
#
# The probability A happens given that I know about B (A is dependant on B possibly)
# Pr(A|B)
#
# Chatbot is a conditional probabiity model, all of next word choices, some are more likely,
#
# Markov, Only find the probability of the next wood based on the current word
#
# Bigram: Depends on 2 two previous words and the current word to determine what the next word will be.
#
# Knowing B does not change the probability of A happening (chatbots that operate indenpend like below are random)
# Pr(A) = P(A|B)

# %% [markdown]
# Multinomial Distributions
# The output of a chatbot is a multinomial distributions.
# You must predict the next word in a list of words.
#
#     Imagine you have a certain number of choices and you can pick multiple (select 2 types of chips from a selection)

# %%
# numerical python
import numpy as np
# scientific python (we use it in stats)
from scipy import stats

# This is an independent 
stats.multinomial(n=2 , p=[0.9, 0.05, 0.05]).rvs(size=1)

# To have it not be dependant its more complex 
# Chatbots work independent of eachother but dependent on their words.
# Out:
# array([[2, 0, 0]])

# %% [markdown]
# Use initial seed, helps for quaility control, the random numbers are generated the same way every time
#
# Read the textbook.
#
# Learn about random.choice() and understand what its doing.

# %% [markdown]
# Independant events P(A)
# dependant events P(A|B)
# iloc
# loc
# indexing by name and numbers
# Chatbots depend on the current word and previous word to determine the next word.
# Chatbots are independent of eachother
# seeds are a way to make sure random genreation happens the same time every time. Good for quality control.
# multinomial distribution
#
# Blue flag beaches - check quaility to make sure its good to swim.

# %% [markdown]
# Lake O

# %% [markdown]
# Do you know how to do composite (multi-part) boolean selection using logical conditionals (with &, |, and ~) to select data? Can you use tuple, list, and dict object types appropriately? How about using a for loop based on a list or not based on a list using range(n) correctly with 0-based indexing?
#
# Do you know what scipy.stats.multinomial and np.random.choice have in common (and what they don't), and what independence and conditional probability might (or might not) have to do with them?
#
# Any chance you might be willing to check out what these weekly optional "ChatBot" surveys are like to see if you might be willing or interested to share your experience using ChatBots in the course so far?
#
# Week 02 ChatBot Experience Survey
#
# This one asks about your experience through what we've been using ChatBots to do in Week 01 and/or Week 02... in case it strikes you that you might have some feedback to share?

# %%
import numpy as np
import pandas as pd
url = "https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2020/2020-08-11/avatar.csv"
avatar = pd.read_csv(url) #avatar.isnull().sum() #avatar[avatar.isnull().sum(axis=1)>0]

# %%
avatar.head()
# Out:
#    id   book  book_num                 chapter  chapter_num  \
# 0   1  Water         1  The Boy in the Iceberg            1
# 1   2  Water         1  The Boy in the Iceberg            1
# 2   3  Water         1  The Boy in the Iceberg            1
# 3   4  Water         1  The Boy in the Iceberg            1
# 4   5  Water         1  The Boy in the Iceberg            1
#
#            character                                          full_text  \
# 0             Katara  Water. Earth. Fire. Air. My grandmother used t...
# 1  Scene Description  As the title card fades, the scene opens onto ...
# 2              Sokka  It's not getting away from me this time. [Clos...
# 3  Scene Description  The shot pans quickly from the boy to Katara, ...
# 4             Katara                  [Happily surprised.] Sokka, look!
#
#                                      character_words  \
# 0  Water. Earth. Fire. Air. My grandmother used t...
# 1                                                NaN
# ...

# %%
avatar.dtypes # Characters are an object, change them to string
# Out:
# id                   int64
# book                object
# book_num             int64
# chapter             object
# chapter_num          int64
# character           object
# full_text           object
# character_words     object
# writer              object
# director            object
# imdb_rating        float64
# dtype: object

# %%
print((avatar['character'].str.upper() + ": " + avatar['full_text'] + "\n\n").values[:4].sum())
# Out:
# KATARA: Water. Earth. Fire. Air. My grandmother used to tell me stories about the old days: a time of peace when the Avatar kept balance between the Water Tribes, Earth Kingdom, Fire Nation and Air Nomads. But that all changed when the Fire Nation attacked. Only the Avatar mastered all four elements; only he could stop the ruthless firebenders. But when the world needed him most, he vanished. A hundred years have passed, and the Fire Nation is nearing victory in the war. Two years ago, my father and the men of my tribe journeyed to the Earth Kingdom to help fight against the Fire Nation, leaving me and my brother to look after our tribe. Some people believe that the Avatar was never reborn into the Air Nomads and that the cycle is broken, but I haven't lost hope. I still believe that, somehow, the Avatar will return to save the world.
#
# ...

# %%
avatar.dtypes
# Out:
# id                   int64
# book                object
# book_num             int64
# chapter             object
# chapter_num          int64
# character           object
# full_text           object
# character_words     object
# writer              object
# director            object
# imdb_rating        float64
# dtype: object

# %%
avatar.character.value_counts()
# Out:
# character
# Scene Description    3393
# Aang                 1796
# Sokka                1639
# Katara               1437
# Zuko                  776
#                      ...
# The Hippo               1
# Audience                1
# Young Mai               1
# Old woman               1
# Katara and Sokka        1
# Name: count, Length: 374, dtype: int64

# %%
avatar['character'].value_counts()
# Counts the number of times that character appears. 
# how many times is katara saying somthing talking.
# Out:
# character
# Scene Description    3393
# Aang                 1796
# Sokka                1639
# Katara               1437
# Zuko                  776
#                      ...
# The Hippo               1
# Audience                1
# Young Mai               1
# Old woman               1
# Katara and Sokka        1
# Name: count, Length: 374, dtype: int64

# %%
# How many entries there are in the chapter. 
avatar.chapter.value_counts()
# Out:
# chapter
# The Fortuneteller                          331
# The Warriors of Kyoshi                     304
# City of Walls and Secrets                  293
# Jet                                        290
# The Desert                                 286
#                                           ...
# The Siege of the North, Part 2             161
# Sozin's Comet, Part 3: Into the Inferno    151
# The Blue Spirit                            144
# Appa's Lost Days                           106
# Sozin's Comet, Part 4: Avatar Aang          91
# Name: count, Length: 61, dtype: int64

# %%
words = ("\n"+avatar.character.str.upper().str.replace(' ','.')+": "+avatar.full_text+" ").sum().split(' ')

# %%
avatar[:10]
# Characters talk in sentences 
# Describing someone action is not the same language
# In full_text there are actions and character speaking.
# Out:
#    id   book  book_num                 chapter  chapter_num  \
# 0   1  Water         1  The Boy in the Iceberg            1
# 1   2  Water         1  The Boy in the Iceberg            1
# 2   3  Water         1  The Boy in the Iceberg            1
# 3   4  Water         1  The Boy in the Iceberg            1
# 4   5  Water         1  The Boy in the Iceberg            1
# 5   6  Water         1  The Boy in the Iceberg            1
# 6   7  Water         1  The Boy in the Iceberg            1
# 7   8  Water         1  The Boy in the Iceberg            1
# 8   9  Water         1  The Boy in the Iceberg            1
# 9  10  Water         1  The Boy in the Iceberg            1
#
#            character                                          full_text  \
# 0             Katara  Water. Earth. Fire. Air. My grandmother used t...
# 1  Scene Description  As the title card fades, the scene opens onto ...
# 2              Sokka  It's not getting away from me this time. [Clos...
# ...

# %%
# from collections import default dict 
# markovian chatbot 
word_used = dict()
next_word = dict()

# loop through each word but remember the index of the word we are at. 
for i,word in enumerate(words[:-1]):
    if word in word_used:
        word_used[word] += 1
    else:
        word_used[word] = 1
        next_word[word] = {}

    if words[i+1] in next_word[word]:
        next_word[word][words[i+1]] += 1
    else:
        next_word[word][words[i+1]] = 1

# %% [markdown]
# word_used = {
#     "katara": 1
# }
#
# next_word = {
#     "katara": {
#         "wind": 1
#     }
# }

# %%
word_used
# Out:
# 63

# %%
next_word['Katara']
# Out:
# {'continues': 2,
#  'is': 72,
#  'to': 13,
#  'follows': 3,
#  'has': 5,
#  'smiles': 8,
#  'and': 249,
#  'nearly': 1,
#  'gets': 5,
#  'points': 4,
#  '...': 3,
#  'as': 24,
#  'turns': 20,
#  'cast': 1,
#  'strays': 1,
#  'grabs': 6,
#  'back,': 1,
#  'hops': 1,
#  'repeatedly': 2,
#  'holding': 5,
#  'gasps': 3,
#  'places': 4,
#  'looks': 35,
#  'glances': 5,
#  'scrambles': 1,
#  'appear': 2,
#  'covers': 3,
#  'crawls': 4,
#  'glares': 4,
#  'perches': 1,
#  'takes': 5,
#  'pulls': 6,
#  'immediately': 2,
#  'away': 1,
#  'opens': 5,
#  'laughs': 1,
#  'approaches': 9,
#  'comes': 5,
#  'laugh.': 2,
#  'use': 2,
#  'ponders': 1,
#  'on': 9,
#  'into': 6,
#  'reach': 1,
#  'down.': 1,
#  'appearing': 1,
#  'approaching': 2,
#  'draw': 1,
#  'had': 1,
#  'with': 13,
#  'remains': 3,
#  'runs': 19,
#  'helping': 1,
#  'quickly': 5,
#  'shoots': 3,
#  'who': 21,
#  'riding': 4,
#  'leaning': 1,
#  'helped': 1,
#  'still': 7,
#  'stare': 3,
#  'sit': 4,
#  'in': 13,
#  'atop': 1,
# ...

# %%
import numpy as np
from scipy import stats

# %%
current_word = "\nKatara:".upper()
print(current_word, end=' ')
for i in range(100):
    probability_of_next_word = np.array(list(next_word[current_word].values()))/word_used[current_word]
    randomly_chosen_next_word = stats.multinomial(p=probability_of_next_word, n=1).rvs(size=1)[0,:]
    current_word = np.array(list(next_word[current_word].keys()))[1==randomly_chosen_next_word][0]
    print(current_word, end=' ')
# Out:
# KATARA: Aang?
# AANG: How do nothing to Iroh's cell. It is shoving Katara who grips the jewelry-making business.
# SCENE.DESCRIPTION: Appa spiraling up.] Take whatever you and Zuko looks at sunset, 370 years in the dragons are you to the army -
# KATARA: [Back to stop him.
# KATARA: I haven't lost today, I don't you know?
# YOUNG.ZUKO: I found Monk Pasang.
# GYATSO: Very well.
# AANG: Then she tripped over.] Blow all part of the friends to her. Cut to the scooter and looks back to Ozai struggling and made a step changes to get in the tail of her cheek, causing Katara

# %% [markdown]
# If we use bigram, we are going to have more combinaion of words in our dictionary appearing less
#
# Actions, characters, spoken words.
#
# descriptions sequence of words
#
# different than
#
# dialogue sequences of words should be different because they speak in a different manner.
#
# Katara talks different than Aang.

# %% [markdown]
# Add all the words that are in description to end in a '-'
# now descritpion words are in a whole new universe of words.
#
# if the word doesnt have a dash its not apart of a description.
#
# or if there is a dash, you're in a description context.
#
#
# words that are in an action context they end with a '_'.

# %%
import re
avatar.full_text = avatar.full_text.apply(lambda string: re.sub(r'\[.*?\]', lambda match: match.group(0).replace(' ', '_ '), string))
avatar.loc[avatar.character=='Scene Description','full_text'] = avatar.full_text[avatar.character=='Scene Description'].str.replace(' ', '- ')
words = ("\n"+avatar.character.str.upper().str.replace(' ','.')+": "+avatar.full_text+" ").sum().split(' ')

# %%
from collections import Counter, defaultdict

# %%
word_used2 = defaultdict(int)
next_word2 = defaultdict(lambda: defaultdict(int))
for i,word in enumerate(words[:-2]):
    word_used2[word+' '+words[i+1]] += 1
    next_word2[word+' '+words[i+1]][words[i+2]] += 1

# %%
# next_word2

# %%
current_word_1 = "\nKatara:".upper()
current_word_2 = "Water."
print(current_word_1, end=' ')
print(current_word_2, end=' ')
for i in range(100):
    probability_of_next_word = np.array(list(next_word2[current_word_1+' '+current_word_2].values()))/word_used2[current_word_1+' '+current_word_2]
    randomly_chosen_next_word = stats.multinomial(p=probability_of_next_word, n=1).rvs(size=1)[0,:]
    current_word_1,current_word_2 = current_word_2,np.array(list(next_word2[current_word_1+' '+current_word_2].keys()))[1==randomly_chosen_next_word][0]
    print(current_word_2.replace('_', '').replace('-', ''), end=' ')
# Out:
# KATARA: Water. Earth. Fire. Air. My grandmother gave my mother this necklace garbage! You promised a scroll!
# ZUKO: I can't handle the hostage trade so you can take the information we need.
# ZUKO: [Voiceover.] Uncle, you're the best!
# DOCK: Me and my brother and uncle, traveling with the current. It'll take us both, so she's trying to help, she would be hiding in the bone and I can handle a little heavy.
# AANG: [Holding up a shell in her hand.] Come on, I found it. The Jasmine Dragon will be the strongest couple in the universe‌?
# SCENE.DESCRIPTION: Cut to a scared look

# %% [markdown]
# Next we need to understand character, who is responding to who. and how do they speak because they sound differently. Currently, we have different language for description, action and dialogue.

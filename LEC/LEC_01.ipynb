# %%
# aliasing, import pandas as pd

# %%
import pandas as pd # alias 
from pandas import read_csv

# %%
url = "https://raw.githubusercontent.com/pointOfive/STA130_F23/main/Data/amazonbooks.csv"
# Two ways to print 
# print(url)
url
# Out:
# 'https://raw.githubusercontent.com/pointOfive/STA130_F23/main/Data/amazonbooks.csv'

# %%
# pandas.read_csv()
# Argument can be a link that is online, or link to a csv in the local directory

# pd.read_csv(url) The problem with this link is that it is not a csv file but a webpage

pd.read_csv(url, encoding='ISO-8859-1')
# Out:
#                                                  Title               Author  \
# 0    1,001 Facts that Will Scare the S#*t Out of Yo...          Cary McNeal
# 1    21: Bringing Down the House - Movie Tie-In: Th...          Ben Mezrich
# 2         100 Best-Loved Poems (Dover Thrift Editions)                Smith
# 3              1421: The Year China Discovered America        Gavin Menzies
# 4      1493: Uncovering the New World Columbus Created      Charles C. Mann
# ..                                                 ...                  ...
# 320                            Where the Sidewalk Ends     Shel Silverstein
# 321                                    White Privilege  Paula S. Rothenberg
# 322                                Why I wore lipstick        Geralyn Lucas
# 323  Worlds Together, Worlds Apart: A History of th...        Robert Tignor
# 324                                  Wuthering Heights         Emily Bronte
#
# ...

# %%
pd.read_csv? #provides the possible arguments.
# Out:
#   Cell In[7], line 1
#     pd.read_csv? #provides the possible arguments.
#                ^
# SyntaxError: invalid syntax

# %%
ab = pd.read_csv(url, encoding="ISO-8859-1")

# %%
print(ab.shape)
# Out:
# (325, 13)

# %%
ab
# Out:
#                                                  Title               Author  \
# 0    1,001 Facts that Will Scare the S#*t Out of Yo...          Cary McNeal
# 1    21: Bringing Down the House - Movie Tie-In: Th...          Ben Mezrich
# 2         100 Best-Loved Poems (Dover Thrift Editions)                Smith
# 3              1421: The Year China Discovered America        Gavin Menzies
# 4      1493: Uncovering the New World Columbus Created      Charles C. Mann
# ..                                                 ...                  ...
# 320                            Where the Sidewalk Ends     Shel Silverstein
# 321                                    White Privilege  Paula S. Rothenberg
# 322                                Why I wore lipstick        Geralyn Lucas
# 323  Worlds Together, Worlds Apart: A History of th...        Robert Tignor
# 324                                  Wuthering Heights         Emily Bronte
#
# ...

# %%
ab.columns
# Out:
# Index(['Title', 'Author', 'List Price', 'Amazon Price', 'Hard_or_Paper',
#        'NumPages', 'Publisher', 'Pub year', 'ISBN-10', 'Height', 'Width',
#        'Thick', 'Weight_oz'],
#       dtype='object')

# %%
ab.isna() #ab.isnull() is an alias for isna()
# The object, ab, knows about the function. When you call the function,
# the object is passed into the function.
# Out:
#      Title  Author  List Price  Amazon Price  Hard_or_Paper  NumPages  \
# 0    False   False       False         False          False     False
# 1    False   False       False         False          False     False
# 2    False   False       False         False          False     False
# 3    False   False       False         False          False     False
# 4    False   False       False         False          False     False
# ..     ...     ...         ...           ...            ...       ...
# 320  False   False       False         False          False     False
# 321  False   False       False         False          False     False
# 322  False   False       False         False          False     False
# 323  False   False       False         False          False     False
# 324  False   False       False         False          False     False
#
#      Publisher  Pub year  ISBN-10  Height  Width  Thick  Weight_oz
# ...

# %%
ab.isna().sum() # isna(ab)
# The dataframe that was created using the function isna() on the object ab is a
# dataframe object that the attribute sum is being called on.
# Out:
# Title            0
# Author           1
# List Price       1
# Amazon Price     0
# Hard_or_Paper    0
# NumPages         2
# Publisher        1
# Pub year         1
# ISBN-10          0
# Height           4
# Width            5
# Thick            1
# Weight_oz        9
# dtype: int64

# %%
ab.isna().sum(axis=0)
# A false counts as one, and a true counts as 0.
# Go down the column and count how many false, or missing values there is.
# Out:
# Title            0
# Author           1
# List Price       1
# Amazon Price     0
# Hard_or_Paper    0
# NumPages         2
# Publisher        1
# Pub year         1
# ISBN-10          0
# Height           4
# Width            5
# Thick            1
# Weight_oz        9
# dtype: int64

# %%
ab.isna().sum(axis=1)

# %%
ab['number of missing per row'] = ab.isna().sum(axis=1)
# Create a new column and assign the values to each one. 
# Be sure not to use an existing column name.

# %%
# ab.isna() # is a dataframe, therefore is a dataframe object

# %%
ab.isna().dtypes # The datatypes were converted to true or false
# Out:
# Title            bool
# Author           bool
# List Price       bool
# Amazon Price     bool
# Hard_or_Paper    bool
# NumPages         bool
# Publisher        bool
# Pub year         bool
# ISBN-10          bool
# Height           bool
# Width            bool
# Thick            bool
# Weight_oz        bool
# dtype: object

# %%
ab.dtypes
# Out:
# Title             object
# Author            object
# List Price       float64
# Amazon Price     float64
# Hard_or_Paper     object
# NumPages         float64
# Publisher         object
# Pub year         float64
# ISBN-10           object
# Height           float64
# Width            float64
# Thick            float64
# Weight_oz        float64
# dtype: object

# %%
ab['NumPages'].dtypes
# Out:
# dtype('float64')

# %%
# ab['NumPages'].astype('int64') This code does not understand how to treat missing values 
ab['NumPages'].dropna().astype('int64')
# Out:
# 0      304
# 1      273
# 2       96
# 3      672
# 4      720
#       ...
# 320    192
# 321    160
# 322    224
# 323    480
# 324    344
# Name: NumPages, Length: 323, dtype: int64

# %%
ab #did the type change in the dataframe?
# Out:
#                                                  Title               Author  \
# 0    1,001 Facts that Will Scare the S#*t Out of Yo...          Cary McNeal
# 1    21: Bringing Down the House - Movie Tie-In: Th...          Ben Mezrich
# 2         100 Best-Loved Poems (Dover Thrift Editions)                Smith
# 3              1421: The Year China Discovered America        Gavin Menzies
# 4      1493: Uncovering the New World Columbus Created      Charles C. Mann
# ..                                                 ...                  ...
# 320                            Where the Sidewalk Ends     Shel Silverstein
# 321                                    White Privilege  Paula S. Rothenberg
# 322                                Why I wore lipstick        Geralyn Lucas
# 323  Worlds Together, Worlds Apart: A History of th...        Robert Tignor
# 324                                  Wuthering Heights         Emily Bronte
#
# ...

# %%
#no, so we need to do this instead.
# ab['NumPages'] = ab['NumPages'].dropna().astype('int64')
# This won't work because there is less data since we dropped missing values 
ab_nonan = ab.dropna().copy()
ab_nonan['NumPages'] = ab_nonan['NumPages'].astype('int64')

# %%
ab_nonan
# Out:
#                                                  Title               Author  \
# 0    1,001 Facts that Will Scare the S#*t Out of Yo...          Cary McNeal
# 1    21: Bringing Down the House - Movie Tie-In: Th...          Ben Mezrich
# 2         100 Best-Loved Poems (Dover Thrift Editions)                Smith
# 3              1421: The Year China Discovered America        Gavin Menzies
# 4      1493: Uncovering the New World Columbus Created      Charles C. Mann
# ..                                                 ...                  ...
# 320                            Where the Sidewalk Ends     Shel Silverstein
# 321                                    White Privilege  Paula S. Rothenberg
# 322                                Why I wore lipstick        Geralyn Lucas
# 323  Worlds Together, Worlds Apart: A History of th...        Robert Tignor
# 324                                  Wuthering Heights         Emily Bronte
#
# ...

# %%
ab_dropna = ab.dropna()
new_data_types = {'Hard_or_Paper': "category", 
                  'NumPages': int,
                  'Pub year': int}
#This can be used to change the values really quick. instead of doing the separately. 
ab = ab.astype(new_data_types)
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[44], line 6
#       2 new_data_types = {'Hard_or_Paper': "category",
#       3                   'NumPages': int,
#       4                   'Pub year': int}
#       5 #This can be used to change the values really quick. instead of doing the separately.
# ----> 6 ab = ab.astype(new_data_types)
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/generic.py:6513, in NDFrame.astype(self, dtype, copy, errors)
#    6511 else:
#    6512     try:
# -> 6513         res_col = col.astype(dtype=cdt, copy=copy, errors=errors)
#    6514     except ValueError as ex:
#    6515         ex.args = (
#    6516             f"{ex}: Error while type casting for column '{col_name}'",
#    6517         )
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/generic.py:6534, in NDFrame.astype(self, dtype, copy, errors)
# ...

# %%
url = "https://raw.githubusercontent.com/KeithGalli/pandas/master/pokemon_data.csv"
# fail https://github.com/KeithGalli/pandas/blob/master/pokemon_data.csv
pokeaman = pd.read_csv(url)
colnames_wtype = {k:k+" ("+v+")" for k,v in zip(pokeaman.columns,pokeaman.dtypes.values.astype(str))}
pokeaman.rename(columns=colnames_wtype, inplace=True)
pokeaman
# Out:
#      # (int64)          Name (object) Type 1 (object) Type 2 (object)  \
# 0            1              Bulbasaur           Grass          Poison
# 1            2                Ivysaur           Grass          Poison
# 2            3               Venusaur           Grass          Poison
# 3            3  VenusaurMega Venusaur           Grass          Poison
# 4            4             Charmander            Fire             NaN
# ..         ...                    ...             ...             ...
# 795        719                Diancie            Rock           Fairy
# 796        719    DiancieMega Diancie            Rock           Fairy
# 797        720    HoopaHoopa Confined         Psychic           Ghost
# 798        720     HoopaHoopa Unbound         Psychic            Dark
# 799        721              Volcanion            Fire           Water
#
#      HP (int64)  Attack (int64)  Defense (int64)  Sp. Atk (int64)  \
# ...

# %%
pokeaman.describe()  # more coercion... if you see it?
# Out:
#         # (int64)  HP (int64)  Attack (int64)  Defense (int64)  \
# count  800.000000  800.000000      800.000000       800.000000
# mean   362.813750   69.258750       79.001250        73.842500
# std    208.343798   25.534669       32.457366        31.183501
# min      1.000000    1.000000        5.000000         5.000000
# 25%    184.750000   50.000000       55.000000        50.000000
# 50%    364.500000   65.000000       75.000000        70.000000
# 75%    539.250000   80.000000      100.000000        90.000000
# max    721.000000  255.000000      190.000000       230.000000
#
#        Sp. Atk (int64)  Sp. Def (int64)  Speed (int64)  Generation (int64)
# count       800.000000       800.000000     800.000000           800.00000
# mean         72.820000        71.902500      68.277500             3.32375
# std          32.722294        27.828916      29.060474             1.66129
# min          10.000000        20.000000       5.000000             1.00000
# ...

# %%
pokeaman['Type 1 (object)'].value_counts()
# How do i find two columns?
# Out:
# Type 1 (object)
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: count, dtype: int64

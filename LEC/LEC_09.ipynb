# %% [markdown]
# What does a hypothesis test TEST?
# A parameter value.
#
# Sample differences - Wrong
# - We already know about the sample, we have the sample, we are trying to determine the parameter.
# -
#
# Correlation - wrong
# Two types of correlation
# - sample correlation
# - population correlation
# We are testing a 0 correlation as the null hypothesis, they're many options so its to vague.
#
# If two different populations of people are different
# - This is to specific, does not consider all the parameters that can be tested.
#
# What does a hypothesis test DO?
# It proves science - wrong
#
# It provides evidence - Right
# - Reject the null hypothesis with the evidence provided.
# What are the difference levels of evidence?
# - 0.1: none
# - 0.1 - 0.05: weak
# - 0.05 - 0.001: moderate
# - 0.001: strong
# Double check this. Always go to the table, and state the evidence that you got on your final.
#
# It provides interference
# - An inference is a range of numbers.
# - Reject the null hypthesis that the correlation is 0.
# - Rejected the null hypothesis.
# Rejecting the null hypothesis, is not interesting because it just rejects, it does not provide an inference on the parameter.
#
# It does what confidence intervals do
#
# First reject the null hypothesis. The correlation is there.
# Provide an inference on the correlations
#
# hypothesis testing
# Estimate: not really important just represents the sample.
# Inteval: reperesents the parameter.
#
#
# What kind if samples have we done hypothesis testing and confidence intervals for?
# - Single Samples
#   we want paired samples in the form of single samples.
#
# - Two Samples
#
# - Paired Sampels
#   You in the past versus you in the future. Time
#   Pair samples are excellent.
#   Started with pair samples, very good.
#   Fall 24 and Winter 25
#
# - (x, Y) regression pairs
#
#
# What information in the data are we attempting to understand when we use hypothesis testing or confidence intervals?
# What the data can tell us about the popualtion.
#
# How srong the evidence is in the data supporting a predefinied belief about the population.
# - This is wrong because there is a difference between estimation and inference.
#
#
# What's regression do?
# It measure the strength of linear association?
#     No, R is the association. We can get to correlation from regression. R^2 proportion of variance explained. We don't do regression to calculate correlation, we can just calculate correlation.
#
# It models the nature of a linear association.
#     Yes, y = mx+b + error. The slope, rise / run, for every amount of change in x the amount of change in y.
#
# It's how we know "The proportion of variation explained' by a model.
#     No, It is not telling you what linear regression is about, it is a different concept.
#
# It provides a hypothesis testing p-value to quantify the degree of evidence the data gives against a non-zero slope null hypothesis (but it can't make confidence intervals).
#     No, any stats model is going to give you inference, statistics is inference, you can do inference on any statistic. simple linear regression has to give you inference. Also, the null hypothesis is a 0 slope. we don't make a null hypothesis of a non zero slope.
#
# 1. Are they related, hypothesis testing
# 2. Strength of linear association
# 3. How does the linear assocaition work?
#    The correlation can be strong, but there can be a very big or small slope.
#    Regression tells us rise over run
#
# What's the difference between linear regression and fitted linear regression?
# 1. the foremr is a normal distribution while the latter is a estimated line and residuals. True
# 2. The former has parameters whole the latter has statistics. True
# 3. The former has residuals while the latter has error terms. False, residuals are for the fitted.
# 4. The former provides inference while the latter only provides estimation (prediction). False, can't do inference because you have no data. You can not do inference on a model (population).
#
#
# hypothesis testing
# p-values
# confidence intervals
#
# Which of these provides a p-value hypothesis testing?
# 1. fitted_model.summary()

# %% [markdown]
# ### Think-Pair-Share
# Sample A has 90 data points. Sample B has 110 data points. No individuals are the same across samples.
# A. What hypothesis testing question might we answer here?
# - Fisher Exact / chi-square test
#
# B. What statistic would you use for these?
# - logistic regression
#
# C. How would that change for difference types of data?
#     a. continuous?
#     - p-value
#     - linear regression
#     b. Binary?
#     - fisher exact
#     - logistic regression
#     c. Categorical
#     - chi-square test
#     - logistic regression
#
# D. Assuing you probably figured out a difference statistic you should use, what will you do? I don't think you know
# - calculate a confidence interval.
#
#
# Doing statistics for two (unpaired) samples
#
# Permutation test
# Two-sample bootstrapped confidence interval
# Indicator variable contrasts
# And what's the difference between ALL of these methods?
# Self Evaluation: what's the correlation of your understand versus the true of the following items?
# AKA what's your 0%-100% (or, techically -100%-100%) understanding level for the following topics?
#
# Bootstrapped Confidence Intervals
# "Coin Flippling" sampling distribution hypothesis testing for "paired samples"
# Calculating p-values based on observed statistics and "sampling distributions under the null"
# Correlation
# The normal "Simple Linear Regression" model
# Fitting Simple Linear Regression models
# Making predictions from linear models
# Using Simple Linear Regression to evaluate the evidence of association between two continue variables
# Assessming the assumptions of Simple Linear Regression using residuals
# Hypothesis testing for two unpaired samples using a permutation test (as opposed to hypothesis testing based on differences for "paired samples")
# Hypothesis testing for two groups (unpaired samples) using indicator variables in Simple Linear Regression
# "Double" bootstrap confidence intervals estimating difference parameters for two groups (unpaired samples)
# Student Lecture Summary
#
# import pandas as pd
#
# url = "https://raw.githubusercontent.com/KeithGalli/pandas/master/pokemon_data.csv"
# # fail https://github.com/KeithGalli/pandas/blob/master/pokemon_data.csv
# pokeaman = pd.read_csv(url)
# pokeaman

# %% [markdown]
# Continuous?
# A. Paired sample?
#
# B. Just one sample
# H_0: average attack value = 100.
# -> by using the min and max value of average attack of pokemon
# Are there any other ideas? We only have a sample of pokemon.
#
# Paired sample
# H_0: average attack = average defence
# -> estiamte
# -> Reject the hypothesis
# -> provide the interval. Bootstrapping.
#
# C.
#
# Is it a single sample?
# Why do you have to shift
#
# unpaired sample?
# how to compare the defence and attack of two different pokemon?
#
# Paired sample, but the data is binary.
#
#
# Legendary pokemon have a higher attack than normal?
# box whisker plot.
#
# permuation test
# double bootstrap
# simple regression
